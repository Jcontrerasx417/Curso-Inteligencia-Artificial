# %% [markdown]
# <a href="https://colab.research.google.com/github/Jcontrerasx417/Curso-Inteligencia-Artificial/blob/main/EDA_Apuntes_de_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA Analisis exploratorio
#
# **Ejemplos**
#
# importar librerias

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.3
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.0
# astropy-iers-data                  0.2025.2.3.0.32.42
# astunparse                         1.6.3
# atpublic                           4.1.0
# attrs                              25.1.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.17.0
# backcall                           0.2.0
# beautifulsoup4                     4.13.3
# bigframes                          1.35.0
# bigquery-magics                    0.5.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             3.0.0
# bokeh                              3.6.3
# Bottleneck                         1.4.2
# bqplot                             0.12.44
# branca                             0.8.1
# CacheControl                       0.14.2
# cachetools                         5.5.1
# catalogue                          2.0.10
# certifi                            2025.1.31
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.1
# chex                               0.1.88
# clarabel                           0.10.0
# click                              8.1.8
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.1
# cmake                              3.31.4
# cmdstanpy                          1.2.5
# colorcet                           3.1.0
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cramjam                            2.9.1
# cryptography                       43.0.3
# cuda-python                        12.6.0
# cudf-cu12                          24.12.0
# cufflinks                          0.17.3
# cupy-cuda12x                       13.3.0
# cvxopt                             1.3.2
# cvxpy                              1.6.0
# cycler                             0.12.1
# cyipopt                            1.5.0
# cymem                              2.0.11
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# db-dtypes                          1.4.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.18
# diffusers                          0.32.2
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.9
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.1.2
# duckdb                             1.1.3
# earthengine-api                    1.5.1
# easydict                           1.13
# editdistance                       0.8.1
# eerepr                             0.1.0
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.11.0
# etuples                            0.3.9
# Farama-Notifications               0.0.4
# fastai                             2.7.18
# fastcore                           1.7.29
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.3
# filelock                           3.17.0
# firebase-admin                     6.6.0
# Flask                              3.1.0
# flatbuffers                        25.1.24
# flax                               0.10.2
# folium                             0.19.4
# fonttools                          4.55.8
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.10.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.12
# GitPython                          3.1.44
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.15
# google-api-core                    2.19.2
# google-api-python-client           2.160.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.79.0
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.17.0
# google-cloud-bigquery-storage      2.28.0
# google-cloud-bigtable              2.28.1
# google-cloud-core                  2.4.1
# google-cloud-dataproc              5.16.0
# google-cloud-datastore             2.20.2
# google-cloud-firestore             2.20.0
# google-cloud-functions             1.19.0
# google-cloud-iam                   2.17.0
# google-cloud-language              2.16.0
# google-cloud-pubsub                2.25.0
# google-cloud-resource-manager      1.14.0
# google-cloud-spanner               3.51.0
# google-cloud-storage               2.19.0
# google-cloud-translate             3.19.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-genai                       0.8.0
# google-generativeai                0.8.4
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# google-spark-connect               0.5.1
# googleapis-common-protos           1.66.0
# googledrivedownloader              1.1.0
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.14.0
# grpc-interceptor                   0.15.4
# grpcio                             1.70.0
# grpcio-status                      1.62.3
# gspread                            6.1.4
# gspread-dataframe                  4.0.0
# gym                                0.25.2
# gym-notices                        0.0.8
# gymnasium                          1.0.0
# h11                                0.14.0
# h5netcdf                           1.5.0
# h5py                               3.12.1
# highspy                            1.9.0
# holidays                           0.66
# holoviews                          1.20.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.1
# huggingface-hub                    0.28.1
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.37.0
# imageio-ffmpeg                     0.6.0
# imagesize                          1.4.1
# imbalanced-learn                   0.13.0
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.6.1
# importlib_resources                6.5.2
# imutils                            0.5.4
# inflect                            7.5.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.4
# intel-openmp                       2025.0.4
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.5
# jiter                              0.8.2
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.1
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.6
# keras                              3.8.0
# keras-hub                          0.18.1
# keras-nlp                          0.18.1
# keyring                            23.5.0
# kiwisolver                         1.4.8
# langchain                          0.3.17
# langchain-core                     0.3.33
# langchain-text-splitters           0.3.5
# langcodes                          3.5.0
# langsmith                          0.3.6
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.12.0
# libkvikio-cu12                     24.12.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.44.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.10.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.1.1
# mizani                             0.13.1
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.4
# more-itertools                     10.6.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multitasking                       0.0.11
# murmurhash                         1.0.12
# music21                            9.3.0
# namex                              0.0.8
# narwhals                           1.25.1
# natsort                            8.4.0
# nbclassic                          1.2.0
# nbclient                           0.10.2
# nbconvert                          7.16.6
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.61.0
# numba-cuda                         0.0.17.1
# numexpr                            2.10.2
# numpy                              1.26.4
# nvidia-cublas-cu12                 12.5.3.2
# nvidia-cuda-cupti-cu12             12.5.82
# nvidia-cuda-nvcc-cu12              12.5.82
# nvidia-cuda-nvrtc-cu12             12.5.82
# nvidia-cuda-runtime-cu12           12.5.82
# nvidia-cudnn-cu12                  9.3.0.75
# nvidia-cufft-cu12                  11.2.3.61
# nvidia-curand-cu12                 10.3.6.82
# nvidia-cusolver-cu12               11.6.3.83
# nvidia-cusparse-cu12               12.5.1.3
# nvidia-nccl-cu12                   2.21.5
# nvidia-nvcomp-cu12                 4.1.0.6
# nvidia-nvjitlink-cu12              12.5.82
# nvidia-nvtx-cu12                   12.4.127
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.12.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# openai                             1.61.1
# opencv-contrib-python              4.11.0.86
# opencv-python                      4.11.0.86
# opencv-python-headless             4.11.0.86
# openpyxl                           3.1.5
# opentelemetry-api                  1.16.0
# opentelemetry-sdk                  1.16.0
# opentelemetry-semantic-conventions 0.37b0
# opt_einsum                         3.4.0
# optax                              0.2.4
# optree                             0.14.0
# orbax-checkpoint                   0.6.4
# orjson                             3.10.15
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.2
# pandas-datareader                  0.10.0
# pandas-gbq                         0.26.1
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.6.0
# param                              2.2.0
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.9
# peft                               0.14.0
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.1.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.5
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.14.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.1
# promise                            2.3
# prompt_toolkit                     3.0.50
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.26.0
# protobuf                           4.25.6
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.6
# pydantic_core                      2.27.2
# pydata-google-auth                 1.9.1
# pydot                              3.0.4
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.17.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.12.0
# pylibcugraph-cu12                  24.12.0
# pylibraft-cu12                     24.12.0
# pymc                               5.20.0
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.5.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.9
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.1
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.4
# pytensor                           2.26.4
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.3.2
# python-dateutil                    2.8.2
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-snappy                      0.7.3
# python-utils                       3.9.1
# pytz                               2025.1
# pyviz_comms                        3.0.4
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post5
# ratelim                            0.1.6
# referencing                        0.36.2
# regex                              2024.11.6
# requests                           2.32.3
# requests-oauthlib                  2.0.0
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.12.1
# rpds-py                            0.22.3
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.5.2
# scikit-image                       0.25.1
# scikit-learn                       1.6.1
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7.post2
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.4.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.20.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.7
# shellingham                        1.5.4
# simple-parsing                     0.1.7
# simsimd                            6.2.1
# six                                1.17.0
# sklearn-compat                     0.1.3
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.1.0
# smmap                              5.0.2
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.13.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# spanner-graph-notebook             1.0.9
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.37
# sqlglot                            25.6.1
# sqlparse                           0.5.3
# srsly                              2.5.1
# stanio                             0.5.1
# statsmodels                        0.14.4
# stringzilla                        3.11.3
# sympy                              1.13.1
# tables                             3.10.2
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.18.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.18.0
# tensorflow-datasets                4.9.7
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.16.1
# tensorflow-probability             0.25.0
# tensorflow-text                    2.18.1
# tensorstore                        0.1.71
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.19.0
# tf_keras                           2.18.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2025.1.10
# timm                               1.0.14
# tinycss2                           1.4.0
# tokenizers                         0.21.0
# toml                               0.10.2
# toolz                              0.12.1
# torch                              2.5.1+cu124
# torchaudio                         2.5.1+cu124
# torchsummary                       1.5.1
# torchvision                        0.20.1+cu124
# tornado                            6.4.2
# tqdm                               4.67.1
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.48.2
# triton                             3.1.0
# tweepy                             4.15.0
# typeguard                          4.4.1
# typer                              0.15.1
# types-pytz                         2025.1.0.20250204
# types-setuptools                   75.8.0.20250210
# typing_extensions                  4.12.2
# tzdata                             2025.1
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.3.0
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.19.6
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# websockets                         14.2
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.2
# xarray                             2025.1.2
# xarray-einstats                    0.8.0
# xgboost                            2.1.3
# xlrd                               2.0.1
# xyzservices                        2025.1.0
# yarl                               1.18.3
# yellowbrick                        1.5
# yfinance                           0.2.52
# zipp                               3.21.0
# zstandard                          0.23.0

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Feb 11 14:27 .
# drwxr-xr-x 1 root root 4096 Feb 12 22:16 ..
# drwxr-xr-x 4 root root 4096 Feb 11 14:27 .config
# drwxr-xr-x 1 root root 4096 Feb 11 14:27 sample_data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.ClassVar

# %%
df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv')

# %%
df.head(10)
# Out:
#    Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 0             4         4.98         153       504000              2
# 1             4         9.14         178       453600              2
# 2             5         4.03         178       728700              3
# 3             4         2.94         187       701400              3
# 4             5         5.33         187       760200              2
# 5             4         5.21         187       602700              3
# 6             4        12.43         152       480900              2
# 7             4        19.15         152       569100              3
# 8             3        29.93         152       346500              1
# 9             4        17.10         152       396900              2

# %%
df.tail()
# Out:
#      Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 484             4         9.67         210       470400              2
# 485             4         9.08         210       432600              2
# 486             4         5.64         210       501900              2
# 487             4         6.48         210       462000              2
# 488             4         7.88         210       249900              1

# %%
df
# Out:
#      Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 0               4         4.98         153       504000              2
# 1               4         9.14         178       453600              2
# 2               5         4.03         178       728700              3
# 3               4         2.94         187       701400              3
# 4               5         5.33         187       760200              2
# ..            ...          ...         ...          ...            ...
# 484             4         9.67         210       470400              2
# 485             4         9.08         210       432600              2
# 486             4         5.64         210       501900              2
# 487             4         6.48         210       462000              2
# 488             4         7.88         210       249900              1
#
# [489 rows x 5 columns]

# %%
df_github=pd.read_csv('https://raw.githubusercontent.com/Jcontrerasx417/Curso-Inteligencia-Artificial/refs/heads/main/vivienda_clasif.csv')

# %%
# prompt: creame 2 arreglos y matriz, el primero llamado saldo, que contiene datos sintéticos del saldo bancario, otro arreglo llamado antiguedad que contiene datos de la antigüedad  de la canta bancaria va de 0 a 10, una matriz de dos columnas que contiene la latitud en la columna 0, y la longitud en la columna 1, con datos muu cercanos a bucaramanga, es decir que varie la latitud y la longitud en decimales o centecimales . El numero de datos son 20. la matriz se llama ubicación. Finalmente quiero que usando column stack me una las matrices y las listas creadas. Defina la semilla aleatoria en 42

import numpy as np

# Set random seed
np.random.seed(42)

# Create saldo array
saldo = np.random.randint(1000, 100000, size=20)

# Create antiguedad array
antiguedad = np.random.randint(0, 11, size=20)

# Create ubicación matrix
# Bucaramanga approximate coordinates: 7.1250° N, 73.1167° W
latitud = np.random.uniform(7.12, 7.13, size=20)
longitud = np.random.uniform(-73.12, -73.11, size=20)
ubicacion = np.column_stack((latitud, longitud))

# Stack arrays and matrix using column_stack
datos_combinados = np.column_stack((saldo, antiguedad, ubicacion))

# Print the resulting array
datos_combinados
# Out:
# array([[ 1.67950000e+04,  4.00000000e+00,  7.12013265e+00,
#         -7.31160485e+01],
#        [ 1.86000000e+03,  0.00000000e+00,  7.12942202e+00,
#         -7.31107334e+01],
#        [ 7.78200000e+04,  9.00000000e+00,  7.12563288e+00,
#         -7.31127273e+01],
#        [ 5.58860000e+04,  5.00000000e+00,  7.12385417e+00,
#         -7.31167346e+01],
#        [ 7.26500000e+03,  8.00000000e+00,  7.12015966e+00,
#         -7.31142956e+01],
#        [ 8.33860000e+04,  0.00000000e+00,  7.12230894e+00,
#         -7.31147917e+01],
#        [ 3.81940000e+04,  1.00000000e+01,  7.12241025e+00,
#         -7.31103883e+01],
#        [ 8.84980000e+04,  1.00000000e+01,  7.12683264e+00,
#         -7.31115547e+01],
#        [ 4.51310000e+04,  9.00000000e+00,  7.12609997e+00,
#         -7.31125268e+01],
#        [ 6.12630000e+04,  2.00000000e+00,  7.12833195e+00,
#         -7.31146031e+01],
#        [ 1.70230000e+04,  6.00000000e+00,  7.12173365e+00,
#         -7.31141325e+01],
#        [ 4.20900000e+04,  3.00000000e+00,  7.12391061e+00,
#         -7.31103474e+01],
#        [ 6.82210000e+04,  8.00000000e+00,  7.12182236e+00,
#         -7.31139297e+01],
#        [ 6.58200000e+04,  2.00000000e+00,  7.12755361e+00,
#         -7.31172400e+01],
#        [ 1.76900000e+03,  4.00000000e+00,  7.12425156e+00,
#         -7.31170373e+01],
#        [ 6.07350000e+04,  2.00000000e+00,  7.12207942e+00,
#         -7.31183473e+01],
#        [ 6.39550000e+04,  6.00000000e+00,  7.12567700e+00,
#         -7.31198436e+01],
#        [ 6.59250000e+04,  4.00000000e+00,  7.12031313e+00,
#         -7.31157660e+01],
#        [ 6.89690000e+04,  8.00000000e+00,  7.12842285e+00,
#         -7.31160512e+01],
#        [ 6.31100000e+03,  6.00000000e+00,  7.12449754e+00,
#         -7.31170651e+01]])

# %%
datos_combinados.shape
# Out:
# (20, 4)

# %%
print( "Media=" ,np.mean(datos_combinados[ 0 ]))
print( "max=" ,np. max (datos_combinados[ 0 ]))
print( "min=" ,np. min (datos_combinados[ 0 ]))
# Out:
# Media= 4183.251021037993
# max= 16795.0
# min= -73.11604849763998

# %%
datos_combinados[:,:] #Exactamente igual a datos_combinados
# Out:
# array([[ 1.67950000e+04,  4.00000000e+00,  7.12013265e+00,
#         -7.31160485e+01],
#        [ 1.86000000e+03,  0.00000000e+00,  7.12942202e+00,
#         -7.31107334e+01],
#        [ 7.78200000e+04,  9.00000000e+00,  7.12563288e+00,
#         -7.31127273e+01],
#        [ 5.58860000e+04,  5.00000000e+00,  7.12385417e+00,
#         -7.31167346e+01],
#        [ 7.26500000e+03,  8.00000000e+00,  7.12015966e+00,
#         -7.31142956e+01],
#        [ 8.33860000e+04,  0.00000000e+00,  7.12230894e+00,
#         -7.31147917e+01],
#        [ 3.81940000e+04,  1.00000000e+01,  7.12241025e+00,
#         -7.31103883e+01],
#        [ 8.84980000e+04,  1.00000000e+01,  7.12683264e+00,
#         -7.31115547e+01],
#        [ 4.51310000e+04,  9.00000000e+00,  7.12609997e+00,
#         -7.31125268e+01],
#        [ 6.12630000e+04,  2.00000000e+00,  7.12833195e+00,
#         -7.31146031e+01],
#        [ 1.70230000e+04,  6.00000000e+00,  7.12173365e+00,
#         -7.31141325e+01],
#        [ 4.20900000e+04,  3.00000000e+00,  7.12391061e+00,
#         -7.31103474e+01],
#        [ 6.82210000e+04,  8.00000000e+00,  7.12182236e+00,
#         -7.31139297e+01],
#        [ 6.58200000e+04,  2.00000000e+00,  7.12755361e+00,
#         -7.31172400e+01],
#        [ 1.76900000e+03,  4.00000000e+00,  7.12425156e+00,
#         -7.31170373e+01],
#        [ 6.07350000e+04,  2.00000000e+00,  7.12207942e+00,
#         -7.31183473e+01],
#        [ 6.39550000e+04,  6.00000000e+00,  7.12567700e+00,
#         -7.31198436e+01],
#        [ 6.59250000e+04,  4.00000000e+00,  7.12031313e+00,
#         -7.31157660e+01],
#        [ 6.89690000e+04,  8.00000000e+00,  7.12842285e+00,
#         -7.31160512e+01],
#        [ 6.31100000e+03,  6.00000000e+00,  7.12449754e+00,
#         -7.31170651e+01]])

# %%
datos_combinados[-5:-1,1:3]
# Out:
# array([[2.        , 7.12207942],
#        [6.        , 7.125677  ],
#        [4.        , 7.12031313],
#        [8.        , 7.12842285]])

# %%
import numpy as np
nombres = np.array(['Sofia', 'Santiago', 'Valentina', 'Mateo', 'Camila', 'Samuel', 'Laura', 'Daniel', 'Manuela', 'Alejandro', 'Salomé', 'Nicolas', 'Mariana', 'Sebastian', 'Gabriela', 'Juan', 'Isabella', 'David', 'Luciana', 'Jose'])
nombres
# Out:
# array(['Sofia', 'Santiago', 'Valentina', 'Mateo', 'Camila', 'Samuel',
#        'Laura', 'Daniel', 'Manuela', 'Alejandro', 'Salomé', 'Nicolas',
#        'Mariana', 'Sebastian', 'Gabriela', 'Juan', 'Isabella', 'David',
#        'Luciana', 'Jose'], dtype='<U9')

# %%
nombres.dtype
# Out:
# dtype('<U9')

# %%
import pandas as pd
# Create a DataFrame
data = {
    'nombre': nombres,
    'saldo': saldo,
    'antiguedad': antiguedad,
    'latitud': latitud,
    'longitud': longitud
}
df_final = pd.DataFrame(data)
print(df_final.head())
# Out:
#       nombre  saldo  antiguedad   latitud   longitud
# 0      Sofia  16795           4  7.120133 -73.116048
# 1   Santiago   1860           0  7.129422 -73.110733
# 2  Valentina  77820           9  7.125633 -73.112727
# 3      Mateo  55886           5  7.123854 -73.116735
# 4     Camila   7265           8  7.120160 -73.114296

# %%
df_final.to_excel("datos.xlsx")

# %%
type(data)
# Out:
# dict

# %%
type(saldo)
# Out:
# numpy.ndarray

# %%
df_final.dtypes
# Out:
# nombre         object
# saldo           int64
# antiguedad      int64
# latitud       float64
# longitud      float64
# dtype: object

# %%
df_final["saldo"].max()
# Out:
# 88498

# %%
df_final.describe().T
# Out:
#             count          mean           std          min           25%  \
# saldo        20.0  46845.800000  28684.574478  1769.000000  16966.000000
# antiguedad   20.0      5.300000      3.197038     0.000000      2.750000
# latitud      20.0      7.124272      0.002896     7.120133      7.122015
# longitud     20.0    -73.114708      0.002705   -73.119844    -73.116810
#
#                      50%           75%           max
# saldo       58310.500000  66499.000000  88498.000000
# antiguedad      5.500000      8.000000     10.000000
# latitud         7.124081      7.126283      7.129422
# longitud      -73.114697    -73.112677    -73.110347

# %%
df_final[df_final.saldo>70000]
# Out:
#       nombre  saldo  antiguedad   latitud   longitud
# 2  Valentina  77820           9  7.125633 -73.112727
# 5     Samuel  83386           0  7.122309 -73.114792
# 7     Daniel  88498          10  7.126833 -73.111555

# %%
print(df_final.iloc[-10:, :2])
# Out:
#        nombre  saldo
# 10     Salomé  17023
# 11    Nicolas  42090
# 12    Mariana  68221
# 13  Sebastian  65820
# 14   Gabriela   1769
# 15       Juan  60735
# 16   Isabella  63955
# 17      David  65925
# 18    Luciana  68969
# 19       Jose   6311

# %%
print(df_final[["nombre","saldo"]].tail(10))
# Out:
#        nombre  saldo
# 10     Salomé  17023
# 11    Nicolas  42090
# 12    Mariana  68221
# 13  Sebastian  65820
# 14   Gabriela   1769
# 15       Juan  60735
# 16   Isabella  63955
# 17      David  65925
# 18    Luciana  68969
# 19       Jose   6311

# %%
print(df_final[["nombre","antiguedad"]].iloc[13:18])
# Out:
#        nombre  antiguedad
# 13  Sebastian           2
# 14   Gabriela           4
# 15       Juan           2
# 16   Isabella           6
# 17      David           4

# %%
df_final_copia=df_final.copy()
df_final_copia
# Out:
#        nombre  saldo  antiguedad   latitud   longitud
# 0       Sofia  16795           4  7.120133 -73.116048
# 1    Santiago   1860           0  7.129422 -73.110733
# 2   Valentina  77820           9  7.125633 -73.112727
# 3       Mateo  55886           5  7.123854 -73.116735
# 4      Camila   7265           8  7.120160 -73.114296
# 5      Samuel  83386           0  7.122309 -73.114792
# 6       Laura  38194          10  7.122410 -73.110388
# 7      Daniel  88498          10  7.126833 -73.111555
# 8     Manuela  45131           9  7.126100 -73.112527
# 9   Alejandro  61263           2  7.128332 -73.114603
# 10     Salomé  17023           6  7.121734 -73.114132
# 11    Nicolas  42090           3  7.123911 -73.110347
# 12    Mariana  68221           8  7.121822 -73.113930
# 13  Sebastian  65820           2  7.127554 -73.117240
# 14   Gabriela   1769           4  7.124252 -73.117037
# 15       Juan  60735           2  7.122079 -73.118347
# 16   Isabella  63955           6  7.125677 -73.119844
# 17      David  65925           4  7.120313 -73.115766
# 18    Luciana  68969           8  7.128423 -73.116051
# 19       Jose   6311           6  7.124498 -73.117065

# %%
df_final.saldo.plot(kind="hist",bins=5,title="Histograma de saldo", figsize=(5,4))
# Out:
# <Axes: title={'center': 'Histograma de saldo'}, ylabel='Frequency'>

# %%
df_final[["saldo","antiguedad"]]iloc[13:18].plot(kind="scater")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-f87ce79eac0c> in <cell line: 0>()
# ----> 1 df_final.saldo.iloc[13:18].plot(kind="scater")
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     958
#     959         if kind not in self._all_kinds:
# --> 960             raise ValueError(
#     961                 f"{kind} is not a valid plot kind "
#     962                 f"Valid plot kinds: {self._all_kinds}"
#
# ValueError: scater is not a valid plot kind Valid plot kinds: ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
import matplotlib.pyplot as plt



# Bar plot
fig, ax = plt.subplots()
ax.barh( df_final.nombre, width= df_final.antiguedad)
ax.set_title("Bar plot")
ax.set_xlabel("antiguedad")
ax.set_ylabel("nombre")
# plt.show()
# Out:
# Text(0, 0.5, 'nombre')

# %%
# Horizontal box plot
fig, ax = plt.subplots()
ax.boxplot(df_final.saldo, vert = True)
# plt.show()
print(df_final.saldo.describe())
# Out:
# count       20.000000
# mean     46845.800000
# std      28684.574478
# min       1769.000000
# 25%      16966.000000
# 50%      58310.500000
# 75%      66499.000000
# max      88498.000000
# Name: saldo, dtype: float64

# %%
import seaborn as sns



# Equivalent to:
sns.kdeplot(x = "saldo", data = df_final)
# Out:
# <Axes: xlabel='saldo', ylabel='Density'>

# %%
df_final.columns
# Out:
# Index(['nombre', 'saldo', 'antiguedad', 'latitud', 'longitud'], dtype='object')

# %%
import plotly.express as px


fig = px.scatter_mapbox(df_final, lat = 'latitud', lon = 'longitud', size = 'saldo',color= 'nombre',
                        zoom = 4, mapbox_style = 'open-street-map')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b37a6b36-f762-4747-aa35-9a4086640c01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b37a6b36-f762-4747-aa35-9a4086640c01")) {                    Plotly.newPlot(                        "b37a6b36-f762-4747-aa35-9a4086640c01",                        [{"hovertemplate":"nombre=Sofia\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.120132649611599],"legendgroup":"Sofia","lon":[-73.11604849763998],"marker":{"color":"#636efa","size":[16795],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Sofia","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Santiago\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.129422017556848],"legendgroup":"Santiago","lon":[-73.11073341134207],"marker":{"color":"#EF553B","size":[1860],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Santiago","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Valentina\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.125632882178455],"legendgroup":"Valentina","lon":[-73.11272728004144],"marker":{"color":"#00cc96","size":[77820],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Valentina","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Mateo\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.123854165025399],"legendgroup":"Mateo","lon":[-73.11673459231194],"marker":{"color":"#ab63fa","size":[55886],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Mateo","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Camila\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.120159662522203],"legendgroup":"Camila","lon":[-73.11429556025595],"marker":{"color":"#FFA15A","size":[7265],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Camila","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Samuel\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.1223089382562215],"legendgroup":"Samuel","lon":[-73.11479165739975],"marker":{"color":"#19d3f3","size":[83386],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Samuel","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Laura\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.12241025466026],"legendgroup":"Laura","lon":[-73.1103882797565],"marker":{"color":"#FF6692","size":[38194],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Laura","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Daniel\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[7.126832635188254],"legendgroup":"Daniel","lon":[-73.11155466151322],"marker":{"color":"#B6E880","size":[88498],"sizemode":"area","sizeref":221.245},"mode":"markers","name":"Daniel","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"nombre=Manuela\u003cbr\u003esaldo=%{marker.size}\u003cbr\u003elatitud=%{lat}\u003cbr\u003elongitud=%{lo ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un dataset simulado
data = {
    "Edad": [23, np.nan, 21, np.nan, 25, 19, 18, 20, np.nan, 22],
    "Género": ["F", "M", np.nan, "M", "F", "F", "M", np.nan, "F", "M"],
    "Calificación": [85, np.nan, 78, 88, np.nan, 92, 75, 80, np.nan, 77],
}
df = pd.DataFrame(data)
dfc['Genero']= dfc ['Género'].fillna(method='ffill')





# Metodo para ver la sumatoria de nulos en el dataframe
df.isnull().sum()
# Out:
# Edad            3
# Género          2
# Calificación    3
# dtype: int64

# %%
# Rellenar valores nulos en "Edad" con la media
df["Edad"] = df["Edad"].fillna(df["Edad"].mean())

# Rellenar valores nulos en "Calificación" con la mediana
df["Calificación"] = df["Calificación"].fillna(df["Calificación"].median())
df
# Out:
#         Edad Género  Calificación
# 0  23.000000      F          85.0
# 1  21.142857      M          80.0
# 2  21.000000    NaN          78.0
# 3  21.142857      M          88.0
# 4  25.000000      F          80.0
# 5  19.000000      F          92.0
# 6  18.000000      M          75.0
# 7  20.000000    NaN          80.0
# 8  21.142857      F          80.0
# 9  22.000000      M          77.0

# %%
# Metodo para ver la sumatoria de nulos en el dataframe
nulos=df.isnull().sum()

# %%
import pandas as pd

# Dataset simulado
data = {
    "ID": [1, 2, 3, 4, 5],
    "Ciudad": ["Madrid", "Barcelona", "Sevilla", "Madrid", "Valencia"],  # Nominal
    "Educación": ["Secundaria", "Primaria", "Universitaria", "Primaria", "Universitaria"],  # Ordinal
    "Género": ["F", "M", "F", "M", "F"],  # Nominal
}
df = pd.DataFrame(data)
print("Dataset original:")
print(df)
# Out:
# Dataset original:
#    ID     Ciudad      Educación Género
# 0   1     Madrid     Secundaria      F
# 1   2  Barcelona       Primaria      M
# 2   3    Sevilla  Universitaria      F
# 3   4     Madrid       Primaria      M
# 4   5   Valencia  Universitaria      F

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub

# Download latest version
path = kagglehub.dataset_download("akshaydattatraykhare/diabetes-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/akshaydattatraykhare/diabetes-dataset?dataset_version_number=1...
# 100%|██████████| 8.91k/8.91k [00:00<00:00, 5.88MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/akshaydattatraykhare/diabetes-dataset/versions/1

# %%
df=pd.read_csv(path+"/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#voy a balacear los datos de df usando la columna Outcome, vamos a usar SMOTE, con oversampling.
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
#del dataframe voy a verificar la columna outcome (el label)si estan balanceados o no
df["Outcome"].value_counts()
#que porcentaje tiene el 0 y el 1
df["Outcome"].value_counts(normalize=True)*100-100
# Out:
# Outcome
# 0   -34.895833
# 1   -65.104167
# Name: proportion, dtype: float64

# %%
import seaborn as sns
#se grafica la bar df.outcome
sns.countplot(x="Outcome",data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
#voy a balancear los datos de df usando la columna Outcome, vamos a usar SMOTE, con oversampling
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
df.shape
# Out:
# (768, 9)

# %%
X=df.drop("Outcome",axis=1)
y=df["Outcome"]
X,y=smote.fit_resample(X,y)

# %%
X.shape
# Out:
# (1000, 8)

# %%
#Vamos a normalizar MinMax los features del dataframe X
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X=scaler.fit_transform(X)
X=pd.DataFrame(X,columns=df.columns[:-1])
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 995     0.176471  0.577889       0.581967       0.303030  0.000000  0.486949
# 996     0.470588  0.793970       0.704918       0.000000  0.000000  0.403675
# 997     0.000000  0.693467       0.000000       0.000000  0.000000  0.634457
# 998     0.176471  0.768844       0.598361       0.000000  0.000000  0.684481
# 999     0.176471  0.608040       0.434426       0.000000  0.000000  0.526633
#
#      DiabetesPedigreeFunction       Age
# 0                    0.234415  0.483333
# 1                    0.116567  0.166667
# 2                    0.253629  0.183333
# 3                    0.038002  0.000000
# 4                    0.943638  0.200000
# ..                        ...       ...
# 995                  0.234121  0.150000
# 996                  0.053569  0.483333
# 997                  0.060197  0.116667
# 998                  0.077664  0.166667
# 999                  0.027928  0.083333
#
# [1000 rows x 8 columns]

# %%
X.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.000000    1000.000000    1000.000000  1000.000000
# mean      0.233235     0.631307       0.567418       0.206515     0.097895
# std       0.196641     0.162434       0.165679       0.163546     0.142536
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       0.058824     0.517588       0.524590       0.000000     0.000000
# 50%       0.176471     0.618090       0.590164       0.232323     0.000000
# 75%       0.352941     0.738693       0.655738       0.333333     0.154255
# max       1.000000     1.000000       1.000000       1.000000     1.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean      0.486165                  0.173006     0.218400
# std       0.113205                  0.136230     0.193447
# min       0.000000                  0.000000     0.000000
# 25%       0.418275                  0.075470     0.066667
# 50%       0.488823                  0.136784     0.166667
# 75%       0.548993                  0.242208     0.337500
# max       1.000000                  1.000000     1.000000

# %%
X.var()
# Out:
# Pregnancies                 0.038668
# Glucose                     0.026385
# BloodPressure               0.027450
# SkinThickness               0.026747
# Insulin                     0.020316
# BMI                         0.012815
# DiabetesPedigreeFunction    0.018559
# Age                         0.037422
# dtype: float64

# %%
#Usar VirianceTrehold para eliminar los features que tengan las varianzas mas bajas <0.1
from sklearn.feature_selection import VarianceThreshold
selector=VarianceThreshold(threshold=0.02)
X_clean=selector.fit_transform(X)
X_clean
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, 0.35353535, 0.        ,
#         0.48333333],
#        [0.05882353, 0.42713568, 0.54098361, 0.29292929, 0.        ,
#         0.16666667],
#        [0.47058824, 0.91959799, 0.52459016, 0.        , 0.        ,
#         0.18333333],
#        ...,
#        [0.        , 0.69346734, 0.        , 0.        , 0.        ,
#         0.11666667],
#        [0.17647059, 0.76884422, 0.59836066, 0.        , 0.        ,
#         0.16666667],
#        [0.17647059, 0.6080402 , 0.43442623, 0.        , 0.        ,
#         0.08333333]])
